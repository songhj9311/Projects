# %%
file = csv.reader(open("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\17년치 실업률.csv", encoding='utf-8'))
print(file)
print(next(file))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23480\1640472394.py in <module>
# ----> 1 file = csv.reader(open("tom_mul_scale.csv", encoding='utf-8'))
#       2 print(file)
#       3 print(next(file))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tom_mul_scale.csv'

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mlp
import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname ="C:\\Windows\\Fonts\\malgun.ttf").get_name()
plt.rc('font',family=font_name)
mlp.rcParams['axes.unicode_minus']=False

# %%
import csv

# %%
import MySQLdb

# %%
config ={"host" : "127.0.0.1", "user" : "root", "password" : "1111", "database" : "Economics"}

# %%
conn =None
try:
    conn = MySQLdb.connect(**config)
    cur=conn.cursor()
    
    file = csv.reader(open("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\17년치 실업률.csv", encoding='utf-8'))
    next(file)
    for i in file:
        cur.execute("INSERT INTO unemployment_rate VALUES(%s, %s)", i)
    
    conn.commit()

except Exception as e:
    print("error : ", e)
finally :
    if conn !=None:
        conn.close()

# %%
seoul_bus = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\2018_bus_count.csv", encoding='utf-8')
seoul_bus
# Out:
#       gu  정류장수
# 0    강남구   534
# 1    강동구   349
# 2    강북구   460
# 3    강서구   576
# 4    관악구   485
# 5    광진구   286
# 6    구로구   478
# 7    금천구   342
# 8    노원구   537
# 9    도봉구   386
# 10  동대문구   318
# 11   동작구   460
# 12   마포구   569
# 13  서대문구   444
# 14   서초구   648
# 15   성동구   439
# 16   성북구   611
# 17   송파구   413
# 18   양천구   363
# 19  영등포구   491
# 20   용산구   349
# 21   은평구   499
# 22   종로구   382
# 23    중구   207
# 24   중랑구   379

# %%
2018 월별 인구이동률

# %%
seoul_pop = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\2022 월별 인구이동률.csv", encoding='utf-8')
seoul_pop
# Out:
#      자치구별  2022년 1월  2022년 2월  2022년 3월  2022년 4월  2022년 5월  2022년 6월  \
# 0   서울특별시  4.598942  6.326203  5.528745  4.368516  4.761597  4.126016
# 1     종로구  4.543044  6.638830  5.163626  4.063817  4.410609  3.876411
# 2      중구  4.538728  6.390233  5.647122  4.254786  4.549155  3.916633
# 3     용산구  4.660841  6.008962  5.280243  4.942809  5.546687  4.788128
# 4     성동구  4.645632  6.787752  5.607546  4.179653  4.377144  4.059497
# 5     광진구  4.679680  6.510431  5.787601  4.408210  4.908434  4.158817
# 6    동대문구  4.420696  6.516716  5.383777  3.821986  4.113889  3.543791
# 7     중랑구  3.934414  5.332506  5.224489  4.082936  4.372415  3.646354
# 8     성북구  4.114760  7.833158  6.398508  4.016885  4.297467  3.647855
# 9     강북구  3.320441  4.731159  4.646053  3.669433  4.201814  3.668441
# 10    도봉구  3.205595  4.319342  4.401596  3.678742  3.903534  3.684316
# 11    노원구  4.483598  5.940004  4.864766  3.410788  3.815853  3.514959
# ...

# %%
seoul_pop.set_index('자치구별', inplace=True)

# %%
seoul_pop.to_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\2022 월별 인구이동률.csv", encoding='utf-8')

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, 서울특별시 to 강동구
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   2018년 1월   26 non-null     float64
#  1   2018년 2월   26 non-null     float64
#  2   2018년 3월   26 non-null     float64
#  3   2018년 4월   26 non-null     float64
#  4   2018년 5월   26 non-null     float64
#  5   2018년 6월   26 non-null     float64
#  6   2018년 7월   26 non-null     float64
#  7   2018년 8월   26 non-null     float64
#  8   2018년 9월   26 non-null     float64
#  9   2018년 10월  26 non-null     float64
#  10  2018년 11월  26 non-null     float64
#  11  2018년 12월  26 non-null     float64
# dtypes: float64(12)
# memory usage: 2.6+ KB

# %%
for i in range(1, 13):
    date= "2020_{} float not null".format(i)
    print(date)
# Out:
# 2020_1 float not null
# 2020_2 float not null
# 2020_3 float not null
# 2020_4 float not null
# 2020_5 float not null
# 2020_6 float not null
# 2020_7 float not null
# 2020_8 float not null
# 2020_9 float not null
# 2020_10 float not null
# 2020_11 float not null
# 2020_12 float not null

# %%
2022_1 float not null,
2022_2 float not null,
2022_3 float not null,
2022_4 float not null,
2022_5 float not null,
2022_6 float not null,
2022_7 float not null,
2022_8 float not null,
2022_9 float not null,
2022_10 float not null,
2022_11 float not null,
2022_12 float not null);
