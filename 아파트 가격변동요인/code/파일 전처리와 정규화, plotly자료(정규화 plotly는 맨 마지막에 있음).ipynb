# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mlp
import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname ="C:\\Windows\\Fonts\\malgun.ttf").get_name()
plt.rc('font',family=font_name)
mlp.rcParams['axes.unicode_minus']=False

# %%
seoul_apt = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\save_point3_apt_buysell_2018_data (2).csv", encoding= 'utf-8')
seoul_apt
# Out:
#     자치구별      본번    부번  전용면적(㎡)      계약년월  거래금액(만원)  1m^2 전용면적당 거래금액(만원)  \
# 0    강남구   479.0   5.0     94.0  201805.0  153334.0               1702.0
# 1    강동구   376.0   4.0     78.0  201805.0   64967.0                858.0
# 2    강북구   768.0   8.0     78.0  201806.0   42267.0                563.0
# 3    강서구   795.0   6.0     75.0  201805.0   53063.0                728.0
# 4    관악구  1497.0  11.0     77.0  201805.0   47147.0                642.0
# 5    광진구   519.0   5.0     87.0  201805.0   80294.0                943.0
# 6    구로구   526.0  14.0     74.0  201806.0   43341.0                595.0
# 7    금천구   874.0   4.0     76.0  201806.0   37864.0                516.0
# 8    노원구   588.0   1.0     66.0  201806.0   38808.0                601.0
# 9    도봉구   426.0   2.0     72.0  201806.0   35758.0                504.0
# 10  동대문구   397.0   3.0     76.0  201805.0   50636.0                693.0
# 11   동작구   481.0   5.0     84.0  201805.0   70567.0                880.0
# ...

# %%
seoul_apt = seoul_apt[['자치구별', '1m^2 전용면적당 거래금액(만원)', '계약연도']]

# %%
seoul_apt
# Out:
#     자치구별  1m^2 전용면적당 거래금액(만원)    계약연도
# 0    강남구               1702.0  2018.0
# 1    강동구                858.0  2018.0
# 2    강북구                563.0  2018.0
# 3    강서구                728.0  2018.0
# 4    관악구                642.0  2018.0
# 5    광진구                943.0  2018.0
# 6    구로구                595.0  2018.0
# 7    금천구                516.0  2018.0
# 8    노원구                601.0  2018.0
# 9    도봉구                504.0  2018.0
# 10  동대문구                693.0  2018.0
# 11   동작구                880.0  2018.0
# 12   마포구                989.0  2018.0
# 13  서대문구                727.0  2018.0
# 14   서초구               1461.0  2018.0
# 15   성동구               1048.0  2018.0
# 16   성북구                629.0  2018.0
# 17   송파구               1201.0  2018.0
# 18   양천구                811.0  2018.0
# 19  영등포구                845.0  2018.0
# 20   용산구               1200.0  2018.0
# 21   은평구                627.0  2018.0
# 22   종로구                764.0  2018.0
# 23    중구                871.0  2018.0
# ...

# %%
seoul_park = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\park_data (2).csv", encoding='utf-8')
seoul_park
# Out:
#     자치구별  공원수
# 0    강남구    7
# 1    강동구    7
# 2    강북구    4
# 3    강서구    9
# 4    과천시    1
# 5    관악구    2
# 6    광진구    2
# 7    구로구    4
# 8    금천구    4
# 9    노원구    2
# 10   도봉구    6
# 11  동대문구    4
# 12   동작구    7
# 13   마포구    5
# 14  서대문구    4
# 15   서초구    6
# 16   성동구    5
# 17   성북구    3
# 18   송파구    7
# 19   양천구    5
# 20  영등포구    5
# 21   용산구    2
# 22   은평구    7
# 23   종로구   12
# 24    중구    5
# 25   중랑구    6

# %%
seoul_merge = pd.merge(seoul_apt, seoul_park, on="자치구별")

# %%
seoul_con = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\gu_year_convinence.csv",encoding='utf-8', index_col=0)
seoul_con
# Out:
#       2017  2018  2019  2020  2021  2022
# 서초구    277   298   314   321   317   323
# 강남구    514   558   597   606   615   627
# 동작구     91   118   141   147   161   172
# 송파구     89   108   123   160   208   243
# 광진구     86   137   181   200   220   233
# 용산구     99   105   118   129   130   135
# 동대문구   126   154   188   188   204   221
# 마포구    196   219   202   183   221   233
# 노원구    122   139   153   165   189   197
# 영등포구   229   263   303   326   330   322
# 강서구    178   209   260   279   282   308
# 성북구     98   121   148   165   180   199
# 성동구     74   108   123   126   144   165
# 종로구     87    87    94    84    85    87
# 중구     167   198   215   213   212   217
# 은평구    115   135   126   148   166   169
# 강북구     82    90   107   122   132   136
# 강동구    181   220   254   268   280   286
# 구로구    136   156   184   207   229   254
# 양천구    125   147   174   186   198   203
# 관악구    221   250   278   265   285   298
# 금천구    103   133   162   173   203   207
# ...

# %%
seoul_con.rename(columns={"2018" : "2018편의점수", "2019" : "2019편의점수", "2020" : "2020편의점수", "2021" : "2021편의점수", "2022" : "2022편의점수"}, inplace=True)

# %%
seoul_con.loc['평균']=seoul_con.sum(axis=0)/25

# %%
seoul_con
# Out:
#       2018편의점수  2019편의점수  2020편의점수  2021편의점수  2022편의점수
# 서초구     298.00     314.0     321.0    317.00    323.00
# 강남구     558.00     597.0     606.0    615.00    627.00
# 동작구     118.00     141.0     147.0    161.00    172.00
# 송파구     108.00     123.0     160.0    208.00    243.00
# 광진구     137.00     181.0     200.0    220.00    233.00
# 용산구     105.00     118.0     129.0    130.00    135.00
# 동대문구    154.00     188.0     188.0    204.00    221.00
# 마포구     219.00     202.0     183.0    221.00    233.00
# 노원구     139.00     153.0     165.0    189.00    197.00
# 영등포구    263.00     303.0     326.0    330.00    322.00
# 강서구     209.00     260.0     279.0    282.00    308.00
# 성북구     121.00     148.0     165.0    180.00    199.00
# 성동구     108.00     123.0     126.0    144.00    165.00
# 종로구      87.00      94.0      84.0     85.00     87.00
# 중구      198.00     215.0     213.0    212.00    217.00
# 은평구     135.00     126.0     148.0    166.00    169.00
# ...

# %%
seoul_con.reset_index(inplace=True)

# %%
seoul_con.rename(columns={"index" : "자치구별"}, inplace=True)

# %%
seoul_con
# Out:
#     자치구별  2018편의점수  2019편의점수  2020편의점수  2021편의점수  2022편의점수
# 0    서초구    298.00     314.0     321.0    317.00    323.00
# 1    강남구    558.00     597.0     606.0    615.00    627.00
# 2    동작구    118.00     141.0     147.0    161.00    172.00
# 3    송파구    108.00     123.0     160.0    208.00    243.00
# 4    광진구    137.00     181.0     200.0    220.00    233.00
# 5    용산구    105.00     118.0     129.0    130.00    135.00
# 6   동대문구    154.00     188.0     188.0    204.00    221.00
# 7    마포구    219.00     202.0     183.0    221.00    233.00
# 8    노원구    139.00     153.0     165.0    189.00    197.00
# 9   영등포구    263.00     303.0     326.0    330.00    322.00
# 10   강서구    209.00     260.0     279.0    282.00    308.00
# 11   성북구    121.00     148.0     165.0    180.00    199.00
# 12   성동구    108.00     123.0     126.0    144.00    165.00
# 13   종로구     87.00      94.0      84.0     85.00     87.00
# 14    중구    198.00     215.0     213.0    212.00    217.00
# ...

# %%
seoul_con.to_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\연도별 서울 편의점수.csv", encoding='utf-8')

# %%
seoul_bus = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\final_bus_gu_year.csv",encoding='utf-8',index_col=0)
seoul_bus
# Out:
#     자치구별  2018  2019  2020  2021  2022
# 0    강남구   534   548   545   520   823
# 1    강동구   349   385   383   365   573
# 2    강북구   460   448   415   409   454
# 3    강서구   576   603   611   569   801
# 4    관악구   485   485   470   467   638
# 5    광진구   286   292   288   270   380
# 6    구로구   478   513   510   497   720
# 7    금천구   342   362   357   342   540
# 8    노원구   537   544   538   527   736
# 9    도봉구   386   391   366   358   448
# 10  동대문구   318   319   311   303   408
# 11   동작구   460   447   440   437   545
# 12   마포구   569   568   570   563   764
# 13  서대문구   444   446   457   454   542
# 14   서초구   648   649   638   605   962
# 15   성동구   439   442   433   445   502
# 16   성북구   611   604   599   601   670
# 17   송파구   413   429   440   414   716
# 18   양천구   363   365   320   317   491
# 19  영등포구   491   504   494   466   679
# 20   용산구   349   344   327   328   441
# 21   은평구   499   511   501   497   725
# 22   종로구   382   375   374   369   472
# ...

# %%
seoul_bus.rename(columns={"2018" : "2018정류장수", "2019" : "2019정류장수", "2020" : "2020정류장수", "2021" : "2021정류장수", "2022" : "2022정류장수"}, inplace=True)

# %%
seoul_bus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   자치구별      25 non-null     object
#  1   2018정류장수  25 non-null     int64
#  2   2019정류장수  25 non-null     int64
#  3   2020정류장수  25 non-null     int64
#  4   2021정류장수  25 non-null     int64
#  5   2022정류장수  25 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.4+ KB

# %%
seoul_bus.loc['평균']=seoul_bus.mean()
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_81804\2127007016.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   seoul_bus.loc['평균']=seoul_bus.mean()

# %%
seoul_bus
# Out:
#     자치구별  2018정류장수  2019정류장수  2020정류장수  2021정류장수  2022정류장수
# 0    강남구     534.0     548.0     545.0    520.00    823.00
# 1    강동구     349.0     385.0     383.0    365.00    573.00
# 2    강북구     460.0     448.0     415.0    409.00    454.00
# 3    강서구     576.0     603.0     611.0    569.00    801.00
# 4    관악구     485.0     485.0     470.0    467.00    638.00
# 5    광진구     286.0     292.0     288.0    270.00    380.00
# 6    구로구     478.0     513.0     510.0    497.00    720.00
# 7    금천구     342.0     362.0     357.0    342.00    540.00
# 8    노원구     537.0     544.0     538.0    527.00    736.00
# 9    도봉구     386.0     391.0     366.0    358.00    448.00
# 10  동대문구     318.0     319.0     311.0    303.00    408.00
# 11   동작구     460.0     447.0     440.0    437.00    545.00
# 12   마포구     569.0     568.0     570.0    563.00    764.00
# 13  서대문구     444.0     446.0     457.0    454.00    542.00
# 14   서초구     648.0     649.0     638.0    605.00    962.00
# ...

# %%
seoul_bus.set_index('자치구별', inplace=True)

# %%
seoul_bus.loc['평균']=seoul_bus.mean()

# %%
seoul_bus.reset_index(inplace=True)

# %%
seoul_bus
# Out:
#     자치구별  2018정류장수  2019정류장수  2020정류장수  2021정류장수  2022정류장수
# 0    강남구     534.0     548.0     545.0    520.00    823.00
# 1    강동구     349.0     385.0     383.0    365.00    573.00
# 2    강북구     460.0     448.0     415.0    409.00    454.00
# 3    강서구     576.0     603.0     611.0    569.00    801.00
# 4    관악구     485.0     485.0     470.0    467.00    638.00
# 5    광진구     286.0     292.0     288.0    270.00    380.00
# 6    구로구     478.0     513.0     510.0    497.00    720.00
# 7    금천구     342.0     362.0     357.0    342.00    540.00
# 8    노원구     537.0     544.0     538.0    527.00    736.00
# 9    도봉구     386.0     391.0     366.0    358.00    448.00
# 10  동대문구     318.0     319.0     311.0    303.00    408.00
# 11   동작구     460.0     447.0     440.0    437.00    545.00
# 12   마포구     569.0     568.0     570.0    563.00    764.00
# 13  서대문구     444.0     446.0     457.0    454.00    542.00
# 14   서초구     648.0     649.0     638.0    605.00    962.00
# ...

# %%
seoul_bus.to_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\연도별 서울 정류장수.csv", encoding='utf-8')

# %%
seoul_merge = pd.merge(seoul_merge2, seoul_bus, left_on='자치구별', right_on='gu')

# %%
seoul_coffee=pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\구별_월별_커피숍개수.csv",encoding='utf-8', index_col=0)
seoul_coffee
# Out:
#       2017-1-31  2017-2-28  2017-3-31  2017-4-30  2017-5-31  2017-6-30  \
# 구로구         399        404        404        404        404        404
# 서초구         921        926        926        926        926        926
# 영등포구        753        766        766        766        766        766
# 서대문구        441        447        447        447        447        447
# 강남구        1586       1586       1586       1586       1586       1586
# 중구         1016       1034       1034       1034       1034       1034
# 송파구         428        440        440        440        440        440
# 종로구         830        838        838        838        838        838
# 마포구         908        916        916        916        916        916
# 성북구         380        391        391        391        391        391
# 동대문구        351        346        346        346        346        346
# 용산구         370        379        379        379        379        379
# ...

# %%
seoul_merge2 = pd.merge(seoul_merge, seoul_coffee, left_on='자치구별', right_on=seoul_coffee.index)

# %%
seoul_coffee = seoul_coffee[['2018-12-31', '2019-12-31', '2020-12-31', '2021-12-31', '2022-12-31']]

# %%
seoul_coffee.loc['평균']=seoul_coffee.sum(axis=0)/25
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_81804\2571460071.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seoul_coffee.loc['평균']=seoul_coffee.sum(axis=0)/25

# %%
seoul_coffee.rename(columns={"2018-12-31" : "2018카페수", "2019-12-31" : "2019카페수", "2020-12-31" : "2020카페수", "2021-12-31" : "2021카페수", "2022-12-31" : "2022카페수"}, inplace=True)
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_81804\1080808573.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seoul_coffee.rename(columns={"2018-12-31" : "2018카페수", "2019-12-31" : "2019카페수", "2020-12-31" : "2020카페수", "2021-12-31" : "2021카페수", "2022-12-31" : "2022카페수"}, inplace=True)

# %%
seoul_coffee.reset_index(inplace=True)

# %%
seoul_coffee.rename(columns={"index" : "자치구별"}, inplace=True)
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_81804\3581533728.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seoul_coffee.rename(columns={"index" : "자치구별"}, inplace=True)

# %%
round(seoul_coffee,2)
# Out:
#     자치구별  2018카페수  2019카페수  2020카페수  2021카페수  2022카페수
# 0    구로구   407.00   414.00   459.00   474.00   488.00
# 1    서초구   949.00   974.00  1005.00  1004.00  1012.00
# 2   영등포구   799.00   844.00   864.00   916.00   899.00
# 3   서대문구   492.00   525.00   522.00   496.00   496.00
# 4    강남구  1679.00  1794.00  1834.00  1873.00  1883.00
# 5     중구  1072.00  1135.00  1149.00  1148.00  1166.00
# 6    송파구   445.00   476.00   585.00   692.00   792.00
# 7    종로구   877.00   896.00   862.00   850.00   873.00
# 8    마포구   943.00   851.00   755.00   906.00   930.00
# 9    성북구   433.00   455.00   492.00   524.00   559.00
# 10  동대문구   395.00   408.00   424.00   427.00   403.00
# 11   용산구   391.00   422.00   444.00   449.00   480.00
# 12   중랑구   247.00   296.00   329.00   367.00   377.00
# 13   강북구   211.00   221.00   243.00   251.00   239.00
# 14   동작구   416.00   439.00   432.00   453.00   465.00
# 15   은평구   387.00   368.00   400.00   408.00   379.00
# ...

# %%
seoul_coffee.to_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\연도별 서울 카페수.csv", encoding='utf-8')

# %%
seoul_cof = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\연도별 서울 카페수.csv", encoding='utf-8', index_col=0)
seoul_cof
# Out:
#       2018카페수  2019카페수  2020카페수  2021카페수  2022카페수
# 자치구별
# 구로구    407.00   414.00   459.00   474.00   488.00
# 서초구    949.00   974.00  1005.00  1004.00  1012.00
# 영등포구   799.00   844.00   864.00   916.00   899.00
# 서대문구   492.00   525.00   522.00   496.00   496.00
# 강남구   1679.00  1794.00  1834.00  1873.00  1883.00
# 중구    1072.00  1135.00  1149.00  1148.00  1166.00
# 송파구    445.00   476.00   585.00   692.00   792.00
# 종로구    877.00   896.00   862.00   850.00   873.00
# 마포구    943.00   851.00   755.00   906.00   930.00
# 성북구    433.00   455.00   492.00   524.00   559.00
# 동대문구   395.00   408.00   424.00   427.00   403.00
# 용산구    391.00   422.00   444.00   449.00   480.00
# 중랑구    247.00   296.00   329.00   367.00   377.00
# 강북구    211.00   221.00   243.00   251.00   239.00
# 동작구    416.00   439.00   432.00   453.00   465.00
# 은평구    387.00   368.00   400.00   408.00   379.00
# 강서구    748.00   842.00   907.00   984.00  1004.00
# 강동구    416.00   471.00   517.00   579.00   608.00
# ...

# %%
len(seoul_cof)
# Out:
# 26

# %%
seoul_apt = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\save_point3_apt_buysell_2018_data.csv", encoding='utf-8', index_col=0)
seoul_apt
# Out:
#         계약연도  계약월  전용면적(㎡)  거래금액(만원)  1m^2 전용면적당 거래금액(만원)
# 자치구별
# 강남구   2018.0  5.0     94.0  153334.0               1702.0
# 강동구   2018.0  5.0     78.0   64967.0                858.0
# 강북구   2018.0  6.0     78.0   42267.0                563.0
# 강서구   2018.0  5.0     75.0   53063.0                728.0
# 관악구   2018.0  5.0     77.0   47147.0                642.0
# 광진구   2018.0  5.0     87.0   80294.0                943.0
# 구로구   2018.0  6.0     74.0   43341.0                595.0
# 금천구   2018.0  6.0     76.0   37864.0                516.0
# 노원구   2018.0  6.0     66.0   38808.0                601.0
# 도봉구   2018.0  6.0     72.0   35758.0                504.0
# 동대문구  2018.0  5.0     76.0   50636.0                693.0
# 동작구   2018.0  5.0     84.0   70567.0                880.0
# 마포구   2018.0  5.0     81.0   78185.0                989.0
# 서대문구  2018.0  5.0     80.0   56398.0                727.0
# 서초구   2018.0  5.0    105.0  146786.0               1461.0
# ...

# %%
seoul_apt.set_index('자치구별', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14896\2667324003.py in <module>
# ----> 1 seoul_apt.set_index('자치구별', inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5501
#    5502         if missing:
# -> 5503             raise KeyError(f"None of {missing} are in the columns")
#    5504
#    5505         if inplace:
#
# KeyError: "None of ['자치구별'] are in the columns"

# %%
len(seoul_apt)
# Out:
# 26

# %%
plt.scatter(seoul_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14896\2586357426.py in <module>
# ----> 1 plt.scatter(seoul_)
#
# NameError: name 'seoul_' is not defined

# %%
seoul_merge = pd.merge(seoul_cof, seoul_apt, left_on=seoul_cof.index, right_on=seoul_apt.index)

# %%
seoul_merge
# Out:
#    key_0  2018카페수  2019카페수  2020카페수  2021카페수  2022카페수    계약연도  계약월  전용면적(㎡)  \
# 0    구로구   407.00   414.00   459.00   474.00   488.00  2018.0  6.0     74.0
# 1    서초구   949.00   974.00  1005.00  1004.00  1012.00  2018.0  5.0    105.0
# 2   영등포구   799.00   844.00   864.00   916.00   899.00  2018.0  5.0     79.0
# 3   서대문구   492.00   525.00   522.00   496.00   496.00  2018.0  5.0     80.0
# 4    강남구  1679.00  1794.00  1834.00  1873.00  1883.00  2018.0  5.0     94.0
# 5     중구  1072.00  1135.00  1149.00  1148.00  1166.00  2018.0  5.0     83.0
# 6    송파구   445.00   476.00   585.00   692.00   792.00  2018.0  5.0     85.0
# 7    종로구   877.00   896.00   862.00   850.00   873.00  2018.0  6.0     82.0
# 8    마포구   943.00   851.00   755.00   906.00   930.00  2018.0  5.0     81.0
# 9    성북구   433.00   455.00   492.00   524.00   559.00  2018.0  5.0     81.0
# 10  동대문구   395.00   408.00   424.00   427.00   403.00  2018.0  5.0     76.0
# ...

# %%
seoul_merge.columns
# Out:
# Index(['key_0', '2018카페수', '2019카페수', '2020카페수', '2021카페수', '2022카페수', '계약연도',
#        '계약월', '전용면적(㎡)', '거래금액(만원)', '1m^2 전용면적당 거래금액(만원)'],
#       dtype='object')

# %%
import plotly.graph_objs as go
import pandas as pd

# 데이터 프레임 df1이 이미 정의되어 있다고 가정합니다.

# 그래프에 사용할 x축을 설정합니다.
x_axis = seoul_merge['key_0']

# 각 feature에 해당하는 y축 데이터를 설정합니다.
y1 = seoul_merge['2018카페수']
y2 = seoul_merge['2019카페수']
y3 = seoul_merge['2020카페수']
y4 = seoul_merge['2021카페수']
y5 = seoul_merge['2022카페수']
y6 = seoul_merge['1m^2 전용면적당 거래금액(만원)']


# 그래프 객체를 생성합니다.
fig = go.Figure()

# trace를 추가합니다.
fig.add_trace(go.Scatter(x=x_axis, y=y1, name='2018카페수'))
# fig.add_trace(go.Scatter(x=x_axis, y=y2, name='물가지수'))
# fig.add_trace(go.Scatter(x=x_axis, y=y3, name='GDP(십억원)'))
# fig.add_trace(go.Scatter(x=x_axis, y=y4, name='기준금리(연%)'))

# 그래프 레이아웃을 설정합니다.
fig.update_layout(title='시계열 그래프', xaxis_title='key_0', yaxis_title='값')

# 그래프를 출력합니다.
fig.show()
# Out:
# <div>                            <div id="1a9313f3-c704-4bea-8e77-2aa3977bc667" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a9313f3-c704-4bea-8e77-2aa3977bc667")) {                    Plotly.newPlot(                        "1a9313f3-c704-4bea-8e77-2aa3977bc667",                        [{"name":"2018\uce74\ud398\uc218","x":["\uad6c\ub85c\uad6c","\uc11c\ucd08\uad6c","\uc601\ub4f1\ud3ec\uad6c","\uc11c\ub300\ubb38\uad6c","\uac15\ub0a8\uad6c","\uc911\uad6c","\uc1a1\ud30c\uad6c","\uc885\ub85c\uad6c","\ub9c8\ud3ec\uad6c","\uc131\ubd81\uad6c","\ub3d9\ub300\ubb38\uad6c","\uc6a9\uc0b0\uad6c","\uc911\ub791\uad6c","\uac15\ubd81\uad6c","\ub3d9\uc791\uad6c","\uc740\ud3c9\uad6c","\uac15\uc11c\uad6c","\uac15\ub3d9\uad6c","\ub3c4\ubd09\uad6c","\uae08\ucc9c\uad6
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.animation as animation
from matplotlib.animation import FuncAnimation
# 데이터 생성

# Figure와 axes 생성
fig, ax = plt.subplots()

# scatter 그래프 생성
line = ax.scatter(seoul_merge['2018카페수'], seoul_merge['1m^2 전용면적당 거래금액(만원)'], 'o')

# animation 함수 정의
def update(frame):
    # 새로운 데이터 생성
    x = seoul_merge['2018카페수']
    y = seoul_merge['1m^2 전용면적당 거래금액(만원)']
    line.set_data(x, y)
    return line

# animation 생성
ani = animation.FuncAnimation(fig, update, frames=100,  blit=True)

# 그래프 출력
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14896\1177066754.py in <module>
#       9
#      10 # scatter 그래프 생성
# ---> 11 line = ax.scatter(seoul_merge['2018카페수'], seoul_merge['1m^2 전용면적당 거래금액(만원)'], 'o')
#      12
#      13 # animation 함수 정의
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4369                 (not np.issubdtype(s.dtype, np.floating) and
# ...

# %%
seoul_merge.plot.scatter()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14896\3593951697.py in <module>
# ----> 1 seoul_merge.plot.scatter()
#
# TypeError: scatter() missing 2 required positional arguments: 'x' and 'y'

# %%
plt.xticks(rotation=90)
plt.scatter(seoul_merge['2018카페수'], seoul_merge['1m^2 전용면적당 거래금액(만원)'], label="2018")
plt.scatter(seoul_merge['2019카페수'], seoul_merge['1m^2 전용면적당 거래금액(만원)'], label="2019")
plt.scatter(seoul_merge['2020카페수'], seoul_merge['1m^2 전용면적당 거래금액(만원)'], label="2020")
plt.scatter(seoul_merge['2021카페수'], seoul_merge['1m^2 전용면적당 거래금액(만원)'], label="2021")
plt.scatter(seoul_merge['2022카페수'], seoul_merge['1m^2 전용면적당 거래금액(만원)'], label="2022")
plt.legend()

# %%
seoul_store = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\연도별 서울 편의점수.csv", encoding='utf-8', index_col=0)
seoul_store
# Out:
#       2018편의점수  2019편의점수  2020편의점수  2021편의점수  2022편의점수
# 자치구별
# 서초구     298.00     314.0     321.0    317.00    323.00
# 강남구     558.00     597.0     606.0    615.00    627.00
# 동작구     118.00     141.0     147.0    161.00    172.00
# 송파구     108.00     123.0     160.0    208.00    243.00
# 광진구     137.00     181.0     200.0    220.00    233.00
# 용산구     105.00     118.0     129.0    130.00    135.00
# 동대문구    154.00     188.0     188.0    204.00    221.00
# 마포구     219.00     202.0     183.0    221.00    233.00
# 노원구     139.00     153.0     165.0    189.00    197.00
# 영등포구    263.00     303.0     326.0    330.00    322.00
# 강서구     209.00     260.0     279.0    282.00    308.00
# 성북구     121.00     148.0     165.0    180.00    199.00
# 성동구     108.00     123.0     126.0    144.00    165.00
# 종로구      87.00      94.0      84.0     85.00     87.00
# 중구      198.00     215.0     213.0    212.00    217.00
# 은평구     135.00     126.0     148.0    166.00    169.00
# ...

# %%
seoul_merge = pd.merge(seoul_store, seoul_apt, left_on=seoul_cof.index, right_on=seoul_apt.index)

# %%
plt.xticks(rotation=90)
plt.scatter(seoul_merge['2018편의점수'], seoul_merge['1m^2 전용면적당 거래금액(만원)'], label="2018")
plt.scatter(seoul_merge['2019편의점수'], seoul_merge['1m^2 전용면적당 거래금액(만원)'], label="2019")
plt.scatter(seoul_merge['2020편의점수'], seoul_merge['1m^2 전용면적당 거래금액(만원)'], label="2020")
plt.scatter(seoul_merge['2021편의점수'], seoul_merge['1m^2 전용면적당 거래금액(만원)'], label="2021")
plt.scatter(seoul_merge['2022편의점수'], seoul_merge['1m^2 전용면적당 거래금액(만원)'], label="2022")
plt.legend()

# %%
seoul_station = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\연도별 서울 정류장수.csv", encoding='utf-8', index_col=0)
seoul_station
# Out:
#       2018정류장수  2019정류장수  2020정류장수  2021정류장수  2022정류장수
# 자치구별
# 강남구      534.0     548.0     545.0    520.00    823.00
# 강동구      349.0     385.0     383.0    365.00    573.00
# 강북구      460.0     448.0     415.0    409.00    454.00
# 강서구      576.0     603.0     611.0    569.00    801.00
# 관악구      485.0     485.0     470.0    467.00    638.00
# 광진구      286.0     292.0     288.0    270.00    380.00
# 구로구      478.0     513.0     510.0    497.00    720.00
# 금천구      342.0     362.0     357.0    342.00    540.00
# 노원구      537.0     544.0     538.0    527.00    736.00
# 도봉구      386.0     391.0     366.0    358.00    448.00
# 동대문구     318.0     319.0     311.0    303.00    408.00
# 동작구      460.0     447.0     440.0    437.00    545.00
# 마포구      569.0     568.0     570.0    563.00    764.00
# 서대문구     444.0     446.0     457.0    454.00    542.00
# 서초구      648.0     649.0     638.0    605.00    962.00
# 성동구      439.0     442.0     433.0    445.00    502.00
# ...

# %%
seoul_merge = pd.merge(seoul_station, seoul_apt, left_on=seoul_cof.index, right_on=seoul_apt.index)

# %%
plt.xticks(rotation=90)
plt.scatter(seoul_merge['2018정류장수'], seoul_merge['1m^2 전용면적당 거래금액(만원)'], label="2018")
plt.scatter(seoul_merge['2019정류장수'], seoul_merge['1m^2 전용면적당 거래금액(만원)'], label="2019")
plt.scatter(seoul_merge['2020정류장수'], seoul_merge['1m^2 전용면적당 거래금액(만원)'], label="2020")
plt.scatter(seoul_merge['2021정류장수'], seoul_merge['1m^2 전용면적당 거래금액(만원)'], label="2021")
plt.scatter(seoul_merge['2022정류장수'], seoul_merge['1m^2 전용면적당 거래금액(만원)'], label="2022")
plt.legend()

# %%
seoul_school = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\18-22고등학교수.csv", encoding='utf-8', index_col=0)
seoul_school
# Out:
#       2018년도고등학교수  2019년도고등학교수  2020년도고등학교수  2021년도고등학교수  2022년도고등학교수
# 자치구별
# 강남구          44.0         44.0           44           44           44
# 강동구          28.0         28.0           28           28           28
# 강북구          14.0         14.0           14           14           14
# 강서구          46.0         46.0           46           46           46
# 관악구          34.0         34.0           34           34           34
# 광진구          18.0         18.0           18           18           18
# 구로구          28.0         28.0           28           28           28
# 금천구          12.0         12.0           12           12           12
# 노원구          50.0         50.0           50           50           50
# 도봉구          20.0         20.0           20           20           20
# 동대문구         22.0         22.0           22           22           22
# 동작구          14.0         14.0           14           14           14
# ...

# %%
seoul_midschool = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\18-22중학교수.csv", encoding='utf-8', index_col=0)
seoul_midschool
# Out:
#       2018학교수  2019학교수  2020학교수  2021학교수  2022학교수
# 자치구별
# 종로구         9        9        9        9        9
# 중구          8        8        8        8        8
# 용산구         9        9        9        9        9
# 성동구        11       11       11       11       11
# 광진구        12       12       12       12       12
# 동대문구       15       15       15       15       15
# 중랑구        14       14       14       14       14
# 성북구        18       18       18       18       18
# 강북구        13       13       13       13       13
# 도봉구        13       13       13       13       13
# 노원구        26       26       26       26       26
# 은평구        18       18       18       18       18
# 서대문구       14       14       14       14       14
# 마포구        14       14       14       14       14
# 양천구        19       19       19       19       19
# 강서구        22       22       22       22       22
# 구로구        13       13       14       14       14
# 금천구         9        9        9        9        9
# ...

# %%
seoul_merge = pd.merge(seoul_school, seoul_midschool|, left_on=seoul_cof.index, right_on=seoul_apt.index)

# %%
seoul_merge = pd.merge(seoul_cof, seoul_apt, left_on=seoul_cof.index, right_on=seoul_apt.index)

# %%
seoul_pop = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\2018인구이동.csv",encoding='utf-8', index_col=0)
seoul_pop
# Out:
#    행정구역(시군구)별  2018 총전입  2018 총전출  2018 순이동  2018 인구이동률(%)
# 2         종로구     23187     24798     -1611           -3.4
# 3          중구     20771     20873      -102           -0.2
# 4         용산구     37339     37801      -462           -0.6
# 5         성동구     51358     49012      2346            2.3
# 6         광진구     55728     58774     -3046           -2.7
# 7        동대문구     54899     57605     -2706           -2.4
# 8         중랑구     54168     59616     -5448           -4.8
# 9         성북구     57147     65477     -8330           -6.8
# 10        강북구     40941     45800     -4859           -5.6
# 11        도봉구     39518     44213     -4695           -5.6
# 12        노원구     61867     72748    -10881           -8.1
# 13        은평구     67489     71519     -4030           -2.9
# 14       서대문구     45861     48484     -2623           -2.8
# 15        마포구     60227     61071      -844           -0.7
# 16        양천구     54579     62414     -7835           -6.7
# ...

# %%
seoul_pop=seoul_pop[['행정구역(시군구)별', '2018 인구이동률(%)']]
seoul_pop
# Out:
#    행정구역(시군구)별  2018 인구이동률(%)
# 2         종로구           -3.4
# 3          중구           -0.2
# 4         용산구           -0.6
# 5         성동구            2.3
# 6         광진구           -2.7
# 7        동대문구           -2.4
# 8         중랑구           -4.8
# 9         성북구           -6.8
# 10        강북구           -5.6
# 11        도봉구           -5.6
# 12        노원구           -8.1
# 13        은평구           -2.9
# 14       서대문구           -2.8
# 15        마포구           -0.7
# 16        양천구           -6.7
# 17        강서구           -3.8
# 18        구로구           -6.8
# 19        금천구           -2.5
# 20       영등포구           -1.8
# 21        동작구           -0.8
# 22        관악구           -1.1
# 23        서초구           -5.6
# 24        강남구           -7.7
# 25        송파구           -0.2
# 26        강동구           -7.5

# %%
seoul_merge=pd.merge(seoul_merge2, seoul_pop, left_on='자치구별', right_on='행정구역(시군구)별')

# %%
seoul_merge
# Out:
#     자치구별  1m^2 전용면적당 거래금액(만원)    계약연도  공원수  2018    gu  정류장수  2018-12-31  \
# 0    강남구               1702.0  2018.0    7   558   강남구   534        1679
# 1    강동구                858.0  2018.0    7   220   강동구   349         416
# 2    강북구                563.0  2018.0    4    90   강북구   460         211
# 3    강서구                728.0  2018.0    9   209   강서구   576         748
# 4    관악구                642.0  2018.0    2   250   관악구   485         479
# 5    광진구                943.0  2018.0    2   137   광진구   286         374
# 6    구로구                595.0  2018.0    4   156   구로구   478         407
# 7    금천구                516.0  2018.0    4   133   금천구   342         324
# 8    노원구                601.0  2018.0    2   139   노원구   537         433
# 9    도봉구                504.0  2018.0    6   113   도봉구   386         229
# 10  동대문구                693.0  2018.0    4   154  동대문구   318         395
# 11   동작구                880.0  2018.0    7   118   동작구   460         416
# ...

# %%
del seoul_merge['gu']
del seoul_merge['행정구역(시군구)별']
del seoul_merge['계약연도']

# %%
seoul_merge
# Out:
#     자치구별  1m^2 전용면적당 거래금액(만원)  공원수  2018  정류장수  2018-12-31  2018 인구이동률(%)
# 0    강남구               1702.0    7   558   534        1679           -7.7
# 1    강동구                858.0    7   220   349         416           -7.5
# 2    강북구                563.0    4    90   460         211           -5.6
# 3    강서구                728.0    9   209   576         748           -3.8
# 4    관악구                642.0    2   250   485         479           -1.1
# 5    광진구                943.0    2   137   286         374           -2.7
# 6    구로구                595.0    4   156   478         407           -6.8
# 7    금천구                516.0    4   133   342         324           -2.5
# 8    노원구                601.0    2   139   537         433           -8.1
# 9    도봉구                504.0    6   113   386         229           -5.6
# 10  동대문구                693.0    4   154   318         395           -2.4
# 11   동작구                880.0    7   118   460         416           -0.8
# ...

# %%
seoul_merge.set_index('자치구별', inplace=True)

# %%
seoul_merge.plot(kind='bar',stacked=True )
# Out:
# <AxesSubplot:xlabel='자치구별'>

# %%
plt.xticks(rotation=90)
plt.bar(seoul_merge['자치구별'], seoul_merge['공원수'], label="park")
# Out:
# <BarContainer object of 25 artists>

# %%
seoul_apt = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\save_point3_apt_rent_2018_data.csv",encoding='utf-8', index_col=0)
seoul_apt
# Out:
#           본번    부번  전용면적(㎡)      계약년월  보증금(만원)  월세(만원)  거래금액(만원)  \
# 자치구별
# 강남구    505.0   3.0     84.0  201807.0  55985.0    43.0   56506.0
# 강동구    398.0   4.0     72.0  201807.0  34220.0    15.0   34398.0
# 강북구    787.0   5.0     73.0  201806.0  24758.0    16.0   24950.0
# 강서구    821.0   4.0     69.0  201807.0  28167.0     8.0   28266.0
# 관악구   1476.0   9.0     66.0  201806.0  25187.0     0.0   25187.0
# 광진구    545.0   4.0     80.0  201807.0  42860.0     0.0   42860.0
# 구로구    539.0  17.0     66.0  201806.0  24226.0     0.0   24226.0
# 금천구    810.0   5.0     63.0  201807.0  20913.0     0.0   20913.0
# 노원구    563.0   1.0     60.0  201806.0  19034.0     0.0   19034.0
# 도봉구    394.0   2.0     65.0  201806.0  18384.0     0.0   18384.0
# 동대문구   485.0   7.0     69.0  201807.0  28163.0     0.0   28163.0
# 동작구    491.0   4.0     77.0  201807.0  39292.0     0.0   39292.0
# 마포구    620.0   2.0     73.0  201807.0  38462.0     0.0   38462.0
# ...

# %%
seoul_apt.reset_index(inplace=True)

# %%
seoul_apt=seoul_apt[['자치구별', '1m^2 전용면적당 거래금액(만원)']]

# %%
seoul_apt.to_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\2018 아파트 전세.csv",encoding='utf-8')

# %%
seoul_apt = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\save_point3_apt_rent_2019_data.csv",encoding='utf-8', index_col=0)
seoul_apt
# Out:
#           본번    부번  전용면적(㎡)      계약년월  보증금(만원)  월세(만원)  거래금액(만원)  \
# 자치구별
# 강남구    531.0   3.0     83.0  201907.0  57530.0    45.0   58067.0
# 강동구    467.0   2.0     70.0  201907.0  32447.0    13.0   32608.0
# 강북구    777.0   6.0     72.0  201907.0  24422.0    15.0   24607.0
# 강서구    801.0   5.0     65.0  201907.0  28178.0     2.0   28197.0
# 관악구   1475.0   9.0     66.0  201907.0  25687.0     0.0   25687.0
# 광진구    536.0   4.0     79.0  201907.0  43047.0     0.0   43047.0
# 구로구    523.0  17.0     66.0  201907.0  24323.0     0.0   24323.0
# 금천구    803.0   7.0     64.0  201907.0  21770.0     0.0   21770.0
# 노원구    564.0   1.0     60.0  201907.0  19427.0     0.0   19427.0
# 도봉구    390.0   2.0     65.0  201907.0  18894.0     0.0   18894.0
# 동대문구   454.0   5.0     67.0  201906.0  27716.0     0.0   27716.0
# 동작구    473.0   5.0     77.0  201906.0  38883.0     0.0   38883.0
# 마포구    564.0   3.0     73.0  201907.0  39462.0     0.0   39462.0
# ...

# %%
seoul_apt.reset_index(inplace=True)

# %%
seoul_apt=seoul_apt[['자치구별', '1m^2 전용면적당 거래금액(만원)']]

# %%
seoul_apt.to_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\2019 아파트 전세.csv",encoding='utf-8')

# %%
seoul_apt = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\save_point3_apt_rent_2020_data.csv",encoding='utf-8', index_col=0)
seoul_apt
# Out:
#           본번    부번  전용면적(㎡)      계약년월  보증금(만원)  월세(만원)  거래금액(만원)  \
# 자치구별
# 강남구    540.0   3.0     83.0  202007.0  65918.0    53.0   66556.0
# 강동구    410.0   3.0     66.0  202006.0  34115.0    19.0   34343.0
# 강북구    761.0   7.0     69.0  202006.0  26970.0    15.0   27152.0
# 강서구    804.0   5.0     63.0  202007.0  28663.0     3.0   28694.0
# 관악구   1497.0   8.0     64.0  202006.0  27325.0     0.0   27325.0
# 광진구    536.0   5.0     78.0  202007.0  47245.0     0.0   47245.0
# 구로구    492.0  16.0     64.0  202007.0  24873.0     0.0   24873.0
# 금천구    813.0   5.0     64.0  202006.0  25058.0     0.0   25058.0
# 노원구    583.0   1.0     60.0  202006.0  21187.0    12.0   21335.0
# 도봉구    383.0   3.0     65.0  202006.0  21104.0    14.0   21273.0
# 동대문구   473.0   4.0     66.0  202006.0  30672.0    21.0   30927.0
# 동작구    519.0   4.0     75.0  202007.0  43731.0    22.0   43992.0
# 마포구    623.0   2.0     64.0  202007.0  35818.0    27.0   36140.0
# ...

# %%
seoul_apt.reset_index(inplace=True)

# %%
seoul_apt=seoul_apt[['자치구별', '1m^2 전용면적당 거래금액(만원)']]

# %%
seoul_apt.to_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\2020 아파트 전세.csv",encoding='utf-8')

# %%
seoul_apt = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\save_point3_apt_rent_2022_data.csv",encoding='utf-8', index_col=0)
seoul_apt
# Out:
#           본번    부번  전용면적(㎡)      계약년월  보증금(만원)  월세(만원)  거래금액(만원)  \
# 자치구별
# 강남구    532.0   3.0     80.0  202206.0  65793.0    83.0   66791.0
# 강동구    436.0   2.0     66.0  202206.0  36132.0    31.0   36500.0
# 강북구    802.0   6.0     60.0  202206.0  23615.0     2.0   23636.0
# 강서구    808.0   4.0     62.0  202207.0  29461.0     0.0   29461.0
# 관악구   1513.0   7.0     61.0  202207.0  28381.0     0.0   28381.0
# 광진구    536.0   5.0     75.0  202206.0  49636.0     0.0   49636.0
# 구로구    487.0  14.0     65.0  202206.0  25129.0     0.0   25129.0
# 금천구    818.0   5.0     60.0  202206.0  25982.0     0.0   25982.0
# 노원구    577.0   1.0     58.0  202206.0  21829.0     0.0   21829.0
# 도봉구    378.0   3.0     61.0  202206.0  20989.0     0.0   20989.0
# 동대문구   488.0   4.0     63.0  202207.0  31862.0     0.0   31862.0
# 동작구    518.0   4.0     73.0  202206.0  44899.0     0.0   44899.0
# 마포구    654.0   2.0     68.0  202206.0  40110.0     0.0   40110.0
# ...

# %%
seoul_apt.reset_index(inplace=True)

# %%
seoul_apt=seoul_apt[['자치구별', '1m^2 전용면적당 거래금액(만원)']]

# %%
seoul_apt.to_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\2022 아파트 전세.csv",encoding='utf-8')

# %%
seoul_apt = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\save_point3_apt_rent_2022_data.csv",encoding='utf-8', index_col=0)
seoul_apt

# %%
seoul_apt = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\save_point3_apt_buysell_2022_data.csv",encoding='utf-8', index_col=0)
seoul_apt
# Out:
#           본번     부번  전용면적(㎡)      계약년월  거래금액(만원)  1m^2 전용면적당 거래금액(만원)    계약연도  \
# 자치구별
# 강남구    480.0    6.0     85.0  202206.0  207409.0               2296.0  2022.0
# 강동구    438.0    4.0     62.0  202206.0   85089.0               1322.0  2022.0
# 강북구    689.0    8.0     55.0  202207.0   50245.0                942.0  2022.0
# 강서구    792.0    9.0     63.0  202206.0   65716.0               1036.0  2022.0
# 관악구   1365.0   18.0     61.0  202205.0   63250.0               1045.0  2022.0
# 광진구    384.0    6.0     72.0  202206.0  104770.0               1424.0  2022.0
# 구로구    409.0   13.0     55.0  202205.0   50468.0                881.0  2022.0
# 금천구    827.0    8.0     48.0  202207.0   45721.0               1014.0  2022.0
# 노원구    598.0    1.0     60.0  202206.0   65202.0               1116.0  2022.0
# 도봉구    420.0    4.0     66.0  202206.0   56234.0                890.0  2022.0
# 동대문구   451.0    7.0     60.0  202206.0   68746.0               1108.0  2022.0
# ...

# %%
seoul_apt.reset_index(inplace=True)

# %%
seoul_apt=seoul_apt[['자치구별', '1m^2 전용면적당 거래금액(만원)']]

# %%
seoul_apt.to_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\2022 아파트 매매가.csv",encoding='utf-8')

# %%
seoul_crime = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\final_crime_gu_year.csv",encoding='utf-8', index_col=0)
seoul_crime
# Out:
#       2018  2019  2020  2021
# 자치구별
# 종로     364   370   272   271
# 중구     357   314   283   282
# 용산     417   362   319   248
# 성동     204   205   171   220
# 광진     363   415   352   325
# 동대문    243   249   244   282
# 중랑     238   212   276   273
# 성북     303   259   212   222
# 강북     273   239   217   222
# 도봉     177   136   131   131
# 노원     293   272   236   293
# 은평     312   283   251   293
# 서대문    278   268   251   292
# 마포     735   673   577   524
# 양천     193   199   189   202
# 강서     424   442   410   434
# 구로     405   363   344   341
# 금천     273   221   183   246
# 영등포    592   520   484   480
# 동작     416   367   305   304
# 관악     545   579   557   528
# 서초     635   785   578   540
# 강남    1010  1280  1048   946
# 송파     515   459   444   496
# 강동     241   280   289   234

# %%
seoul_crime.reset_index(inplace=True)

# %%
seoul_crime
# Out:
#    자치구별  2018  2019  2020  2021
# 0    종로   364   370   272   271
# 1    중구   357   314   283   282
# 2    용산   417   362   319   248
# 3    성동   204   205   171   220
# 4    광진   363   415   352   325
# 5   동대문   243   249   244   282
# 6    중랑   238   212   276   273
# 7    성북   303   259   212   222
# 8    강북   273   239   217   222
# 9    도봉   177   136   131   131
# 10   노원   293   272   236   293
# 11   은평   312   283   251   293
# 12  서대문   278   268   251   292
# 13   마포   735   673   577   524
# 14   양천   193   199   189   202
# 15   강서   424   442   410   434
# 16   구로   405   363   344   341
# 17   금천   273   221   183   246
# 18  영등포   592   520   484   480
# 19   동작   416   367   305   304
# 20   관악   545   579   557   528
# 21   서초   635   785   578   540
# 22   강남  1010  1280  1048   946
# 23   송파   515   459   444   496
# 24   강동   241   280   289   234

# %%
seoul_crime['자치구별']=seoul_crime['자치구별']+"구"

# %%
seoul_crime['자치구별'][1]='중구'
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_14896\3754588216.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seoul_crime['자치구별'][1]='중구'

# %%
seoul_crime.set_index('자치구별', inplace=True)

# %%
seoul_crime.to_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\연도별 범죄수.csv",encoding='utf-8')

# %%
seoul_rate = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\한국은행 기준금리 및 여수신금리_20122221.csv",encoding='utf-8')
seoul_rate
# Out:
#                         통계표       계정항목  단위   변환  2006/Q1  2006/Q2  2006/Q3  \
# 0  1.3.1. 한국은행 기준금리 및 여수신금리  한국은행 기준금리  연%  원자료      4.0     4.25      4.5
#
#    2006/Q4  2007/Q1  2007/Q2  ...  2020/Q3  2020/Q4  2021/Q1  2021/Q2  \
# 0      4.5      4.5      4.5  ...      0.5      0.5      0.5      0.5
#
#    2021/Q3  2021/Q4  2022/Q1  2022/Q2  2022/Q3  2022/Q4
# 0     0.75      1.0     1.25     1.75      2.5     3.25
#
# [1 rows x 72 columns]

# %%
del seoul_rate['통계표']

# %%
del seoul_rate['단위']

# %%
del seoul_rate['변환']

# %%
seoul_rate['계정항목'][0]='기준금리(연%)'
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_14896\1361369111.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seoul_rate['계정항목'][0]='기준금리(연%)'

# %%
seoul_rate
# Out:
#        계정항목  2006/Q1  2006/Q2  2006/Q3  2006/Q4  2007/Q1  2007/Q2  2007/Q3  \
# 0  기준금리(연%)      4.0     4.25      4.5      4.5      4.5      4.5      5.0
#
#    2007/Q4  2008/Q1  ...  2020/Q3  2020/Q4  2021/Q1  2021/Q2  2021/Q3  \
# 0      5.0      5.0  ...      0.5      0.5      0.5      0.5     0.75
#
#    2021/Q4  2022/Q1  2022/Q2  2022/Q3  2022/Q4
# 0      1.0     1.25     1.75      2.5     3.25
#
# [1 rows x 69 columns]

# %%
seoul_rate.set_index('계정항목', inplace=True)

# %%
seoul_rate2 = seoul_rate.T

# %%
seoul_rate2.index
# Out:
# Index(['2006/Q1', '2006/Q2', '2006/Q3', '2006/Q4', '2007/Q1', '2007/Q2',
#        '2007/Q3', '2007/Q4', '2008/Q1', '2008/Q2', '2008/Q3', '2008/Q4',
#        '2009/Q1', '2009/Q2', '2009/Q3', '2009/Q4', '2010/Q1', '2010/Q2',
#        '2010/Q3', '2010/Q4', '2011/Q1', '2011/Q2', '2011/Q3', '2011/Q4',
#        '2012/Q1', '2012/Q2', '2012/Q3', '2012/Q4', '2013/Q1', '2013/Q2',
#        '2013/Q3', '2013/Q4', '2014/Q1', '2014/Q2', '2014/Q3', '2014/Q4',
#        '2015/Q1', '2015/Q2', '2015/Q3', '2015/Q4', '2016/Q1', '2016/Q2',
#        '2016/Q3', '2016/Q4', '2017/Q1', '2017/Q2', '2017/Q3', '2017/Q4',
#        '2018/Q1', '2018/Q2', '2018/Q3', '2018/Q4', '2019/Q1', '2019/Q2',
#        '2019/Q3', '2019/Q4', '2020/Q1', '2020/Q2', '2020/Q3', '2020/Q4',
#        '2021/Q1', '2021/Q2', '2021/Q3', '2021/Q4', '2022/Q1', '2022/Q2',
#        '2022/Q3', '2022/Q4'],
#       dtype='object')

# %%
# %matplotlib inline
seoul_rate2.plot.line()
# Out:
# <AxesSubplot:>

# %%
seoul_rate2.to_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\17년치 기준금리.csv",encoding='utf-8')

# %%
seoul_price = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\국내총생산에 대한 지출(계절조정, 명목, 분기)_20122312.csv",encoding='utf-8')
seoul_price
# Out:
#                                      통계표          계정항목    단위   변환    2006/Q1  \
# 0  2.1.2.2.1. 국내총생산에 대한 지출(계절조정, 명목, 분기)  국내총생산에 대한 지출  십억원   원자료  246,614.4
#
#      2006/Q2    2006/Q3    2006/Q4    2007/Q1    2007/Q2  ...    2020/Q3  \
# 0  248,152.7  253,912.6  256,921.7  263,441.3  269,569.3  ...  489,772.8
#
#      2020/Q4    2021/Q1    2021/Q2    2021/Q3    2021/Q4    2022/Q1  \
# 0  494,927.7  504,874.5  514,696.4  521,818.2  530,268.9  532,765.7
#
#      2022/Q2    2022/Q3    2022/Q4
# 0  540,784.3  538,803.8  539,324.4
#
# [1 rows x 72 columns]

# %%
seoul_price
# Out:
#                                         통계표              계정항목    단위   변환  \
# 0  2.1.2.1.1. 경제활동별 GDP 및 GNI(계절조정, 명목, 분기)  국내총생산(시장가격, GDP)  십억원   원자료
#
#      2002/Q4  2003/Q1    2003/Q2    2003/Q3    2003/Q4    2004/Q1  ...  \
# 0  202,024.8  204,578  206,438.4  209,440.8  216,907.9  222,334.9  ...
#
#      2020/Q3    2020/Q4    2021/Q1    2021/Q2    2021/Q3    2021/Q4  \
# 0  489,772.8  494,927.7  504,874.5  514,696.4  521,818.2  530,268.9
#
#      2022/Q1    2022/Q2    2022/Q3    2022/Q4
# 0  532,765.7  540,784.3  538,803.8  539,324.4
#
# [1 rows x 85 columns]

# %%
seoul_price['계정항목'][0]='GDP(십억원)'

# %%
del seoul_price['통계표']

# %%
del seoul_price['단위']

# %%
del seoul_price['변환']

# %%
seoul_price
# Out:
#        계정항목    2006/Q1    2006/Q2    2006/Q3    2006/Q4    2007/Q1    2007/Q2  \
# 0  GDP(십억원)  246,614.4  248,152.7  253,912.6  256,921.7  263,441.3  269,569.3
#
#      2007/Q3    2007/Q4    2008/Q1  ...    2020/Q3    2020/Q4    2021/Q1  \
# 0  274,329.9  282,319.7  283,234.3  ...  489,772.8  494,927.7  504,874.5
#
#      2021/Q2    2021/Q3    2021/Q4    2022/Q1    2022/Q2    2022/Q3    2022/Q4
# 0  514,696.4  521,818.2  530,268.9  532,765.7  540,784.3  538,803.8  539,324.4
#
# [1 rows x 69 columns]

# %%
seoul_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, GDP(십억원) to GDP(십억원)
# Data columns (total 68 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   2006/Q1  1 non-null      object
#  1   2006/Q2  1 non-null      object
#  2   2006/Q3  1 non-null      object
#  3   2006/Q4  1 non-null      object
#  4   2007/Q1  1 non-null      object
#  5   2007/Q2  1 non-null      object
#  6   2007/Q3  1 non-null      object
#  7   2007/Q4  1 non-null      object
#  8   2008/Q1  1 non-null      object
#  9   2008/Q2  1 non-null      object
#  10  2008/Q3  1 non-null      object
#  11  2008/Q4  1 non-null      object
#  12  2009/Q1  1 non-null      object
#  13  2009/Q2  1 non-null      object
#  14  2009/Q3  1 non-null      object
#  15  2009/Q4  1 non-null      object
#  16  2010/Q1  1 non-null      object
#  17  2010/Q2  1 non-null      object
#  18  2010/Q3  1 non-null      object
#  19  2010/Q4  1 non-null      object
# ...

# %%
seoul_price.reset_index('계정항목', inplace=True)

# %%
seoul_price2 =seoul_price.T

# %%
seoul_price2
# Out:
#                  0
# 계정항목      GDP(십억원)
# 2006/Q1  246,614.4
# 2006/Q2  248,152.7
# 2006/Q3  253,912.6
# 2006/Q4  256,921.7
# ...            ...
# 2021/Q4  530,268.9
# 2022/Q1  532,765.7
# 2022/Q2  540,784.3
# 2022/Q3  538,803.8
# 2022/Q4  539,324.4
#
# [69 rows x 1 columns]

# %%
soul_price2 = seoul_price.iloc[0,:].str.replace(",","").astype(float)

# %%
seoul_price2.to_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\20년치 GDP분기.csv", encoding="utf-8")

# %%
seoul_price3 = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\20년치 GDP분기.csv", encoding="utf-8", index_col=0, header=1)
seoul_price3
# Out:
#           GDP(십억원)
# 계정항목
# 2006/Q1  246,614.4
# 2006/Q2  248,152.7
# 2006/Q3  253,912.6
# 2006/Q4  256,921.7
# 2007/Q1  263,441.3
# ...            ...
# 2021/Q4  530,268.9
# 2022/Q1  532,765.7
# 2022/Q2  540,784.3
# 2022/Q3  538,803.8
# 2022/Q4  539,324.4
#
# [68 rows x 1 columns]

# %%
seoul_price4 = seoul_price3['GDP(십억원)'].str.replace(",", "").astype(float)

# %%
seoul_price4.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 68 entries, 2006/Q1 to 2022/Q4
# Series name: GDP(십억원)
# Non-Null Count  Dtype
# --------------  -----
# 68 non-null     float64
# dtypes: float64(1)
# memory usage: 1.1+ KB

# %%
seoul_price4.to_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\17년치 GDP분기.csv", encoding="utf-8")

# %%
seoul_price4.plot.line()
# Out:
# <AxesSubplot:xlabel='계정항목'>

# %%
seoul_pr= pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\소비자물가지수_20122252.csv", encoding="utf-8")
seoul_pr
# Out:
#               통계표 계정항목        단위   가중치   변환  2006/Q1  2006/Q2  2006/Q3  \
# 0  4.2.1. 소비자물가지수  총지수  2020=100  1000  원자료    75.48   75.951   76.571
#
#    2006/Q4  2007/Q1  ...  2020/Q3  2020/Q4  2021/Q1  2021/Q2  2021/Q3  \
# 0   76.323   76.992  ...   100.19    100.2   101.49   102.03   102.73
#
#    2021/Q4  2022/Q1  2022/Q2  2022/Q3  2022/Q4
# 0   103.75   105.35   107.54   108.76    109.2
#
# [1 rows x 73 columns]

# %%
del seoul_pr['통계표']

# %%
del seoul_pr['단위']

# %%
del seoul_pr['가중치']

# %%
del seoul_pr['변환']

# %%
 seoul_pr['계정항목'][0]='물가지수'
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_14896\230083932.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seoul_pr['계정항목'][0]='물가지수'

# %%
seoul_pr.set_index('계정항목', inplace=True)

# %%
seoul_pr2 = seoul_pr.T

# %%
seoul_pr2
# Out:
# 계정항목        물가지수
# 2006/Q1   75.480
# 2006/Q2   75.951
# 2006/Q3   76.571
# 2006/Q4   76.323
# 2007/Q1   76.992
# ...          ...
# 2021/Q4  103.750
# 2022/Q1  105.350
# 2022/Q2  107.540
# 2022/Q3  108.760
# 2022/Q4  109.200
#
# [68 rows x 1 columns]

# %%
seoul_pr2.plot.line()
# Out:
# <AxesSubplot:>

# %%
seoul_pr2.to_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\17년치 물가지수분기.csv", encoding="utf-8")

# %%
seoul_price2.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 81 entries, 2002/Q4 to 2022/Q4
# Series name: GDP(십억원)
# Non-Null Count  Dtype
# --------------  -----
# 81 non-null     object
# dtypes: object(1)
# memory usage: 3.3+ KB

# %%
del seoul_price['통계표']

# %%
del seoul_price['단위']

# %%
del seoul_price['변환']

# %%
seoul_job= pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\행정구역_시도__성별_실업률_20230420130924.csv", encoding="cp949")
seoul_job
# Out:
#      시도별 성별  2006.1/4  2006.2/4  2006.3/4  2006.4/4  2007.1/4  2007.2/4  \
# 0  서울특별시  계       5.2       4.3       4.3       4.5       4.5       3.9
#
#    2007.3/4  2007.4/4  ...  2020.3/4  2020.4/4  2021.1/4  2021.2/4  2021.3/4  \
# 0       3.9       4.0  ...       4.0       4.4       6.1       5.2       4.0
#
#    2021.4/4  2022.1/4  2022.2/4  2022.3/4  2022.4/4
# 0       4.0       4.4       3.6       2.8       2.9
#
# [1 rows x 70 columns]

# %%
del seoul_job['시도별']

# %%
seoul_job.rename(columns={"성별" : "실업률(%)"},inplace=True)

# %%
seoul_job.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 69 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   실업률(%)    1 non-null      object
#  1   2006.1/4  1 non-null      float64
#  2   2006.2/4  1 non-null      float64
#  3   2006.3/4  1 non-null      float64
#  4   2006.4/4  1 non-null      float64
#  5   2007.1/4  1 non-null      float64
#  6   2007.2/4  1 non-null      float64
#  7   2007.3/4  1 non-null      float64
#  8   2007.4/4  1 non-null      float64
#  9   2008.1/4  1 non-null      float64
#  10  2008.2/4  1 non-null      float64
#  11  2008.3/4  1 non-null      float64
#  12  2008.4/4  1 non-null      float64
#  13  2009.1/4  1 non-null      float64
#  14  2009.2/4  1 non-null      float64
#  15  2009.3/4  1 non-null      float64
#  16  2009.4/4  1 non-null      float64
#  17  2010.1/4  1 non-null      float64
#  18  2010.2/4  1 non-null      float64
# ...

# %%
seoul_job.set_index("실업률(%)", inplace=True)

# %%
seoul_job2 = seoul_job.T

# %%
seoul_job2
# Out:
# 실업률(%)      계
# 2006.1/4  5.2
# 2006.2/4  4.3
# 2006.3/4  4.3
# 2006.4/4  4.5
# 2007.1/4  4.5
# ...       ...
# 2021.4/4  4.0
# 2022.1/4  4.4
# 2022.2/4  3.6
# 2022.3/4  2.8
# 2022.4/4  2.9
#
# [68 rows x 1 columns]

# %%
seoul_job2.plot.line()
# Out:
# <AxesSubplot:>

# %%
Q1 = [1, 2, 3]
Q2 = [4, 5, 6]
Q3 = [7, 8, 9]
Q4 = [10, 11, 12]

# 계약월을 분기로 변환하는 함수 정의

def get_quarter(month):
    if month in Q1:
        return 'Q1'
    elif month in Q2:
        return 'Q2'
    elif month in Q3:
        return 'Q3'
    else:
        return 'Q4'

# 분기 컬럼 생성
df2['분기'] = df2['계약월'].apply(get_quarter)

df2

# %%
seoul_job2.to_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\17년치 실업률.csv", encoding="utf-8")

# %%
seoul_apt = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\2006-2022_quarter_apt_buysell_average_price.csv", encoding="utf-8", index_col=0)
seoul_apt
# Out:
#        계정항목  1m^2 전용면적당 거래금액(만원)
# 0   2006/Q1                497.0
# 1   2006/Q2                424.0
# 2   2006/Q3                407.0
# 3   2006/Q4                462.0
# 0   2007/Q1                393.0
# ..      ...                  ...
# 3   2021/Q4               1443.0
# 0   2022/Q1               1382.0
# 1   2022/Q2               1452.0
# 2   2022/Q3               1269.0
# 3   2022/Q4               1249.0
#
# [68 rows x 2 columns]

# %%
seoul_apt.set_index('계정항목', inplace=True)

# %%
seoul_merge = pd.merge(seoul_apt, seoul_rate2, left_on=seoul_apt.index, right_on=seoul_rate2.index)
seoul_merge
# Out:
#       key_0  1m^2 전용면적당 거래금액(만원)  기준금리(연%)
# 0   2006/Q1                497.0      4.00
# 1   2006/Q2                424.0      4.25
# 2   2006/Q3                407.0      4.50
# 3   2006/Q4                462.0      4.50
# 4   2007/Q1                393.0      4.50
# ..      ...                  ...       ...
# 63  2021/Q4               1443.0      1.00
# 64  2022/Q1               1382.0      1.25
# 65  2022/Q2               1452.0      1.75
# 66  2022/Q3               1269.0      2.50
# 67  2022/Q4               1249.0      3.25
#
# [68 rows x 3 columns]

# %%
seoul_merge2 = pd.merge(seoul_price4, seoul_merge, left_on=seoul_price4.index, right_on='key_0')
seoul_merge2
# Out:
#     GDP(십억원)    key_0  1m^2 전용면적당 거래금액(만원)  기준금리(연%)
# 0   246614.4  2006/Q1                497.0      4.00
# 1   248152.7  2006/Q2                424.0      4.25
# 2   253912.6  2006/Q3                407.0      4.50
# 3   256921.7  2006/Q4                462.0      4.50
# 4   263441.3  2007/Q1                393.0      4.50
# ..       ...      ...                  ...       ...
# 63  530268.9  2021/Q4               1443.0      1.00
# 64  532765.7  2022/Q1               1382.0      1.25
# 65  540784.3  2022/Q2               1452.0      1.75
# 66  538803.8  2022/Q3               1269.0      2.50
# 67  539324.4  2022/Q4               1249.0      3.25
#
# [68 rows x 4 columns]

# %%
seoul_merge = pd.merge(seoul_pr2, seoul_merge2, left_on=seoul_pr2.index, right_on="key_0")
seoul_merge
# Out:
#        물가지수  GDP(십억원)    key_0  1m^2 전용면적당 거래금액(만원)  기준금리(연%)
# 0    75.480  246614.4  2006/Q1                497.0      4.00
# 1    75.951  248152.7  2006/Q2                424.0      4.25
# 2    76.571  253912.6  2006/Q3                407.0      4.50
# 3    76.323  256921.7  2006/Q4                462.0      4.50
# 4    76.992  263441.3  2007/Q1                393.0      4.50
# ..      ...       ...      ...                  ...       ...
# 63  103.750  530268.9  2021/Q4               1443.0      1.00
# 64  105.350  532765.7  2022/Q1               1382.0      1.25
# 65  107.540  540784.3  2022/Q2               1452.0      1.75
# 66  108.760  538803.8  2022/Q3               1269.0      2.50
# 67  109.200  539324.4  2022/Q4               1249.0      3.25
#
# [68 rows x 5 columns]

# %%
seoul_merge.to_csv("")
# Out:
#        물가지수  GDP(십억원)    key_0  1m^2 전용면적당 거래금액(만원)  기준금리(연%)
# 0    75.480  246614.4  2006/Q1                497.0      4.00
# 1    75.951  248152.7  2006/Q2                424.0      4.25
# 2    76.571  253912.6  2006/Q3                407.0      4.50
# 3    76.323  256921.7  2006/Q4                462.0      4.50
# 4    76.992  263441.3  2007/Q1                393.0      4.50
# ..      ...       ...      ...                  ...       ...
# 63  103.750  530268.9  2021/Q4               1443.0      1.00
# 64  105.350  532765.7  2022/Q1               1382.0      1.25
# 65  107.540  540784.3  2022/Q2               1452.0      1.75
# 66  108.760  538803.8  2022/Q3               1269.0      2.50
# 67  109.200  539324.4  2022/Q4               1249.0      3.25
#
# [68 rows x 5 columns]

# %%
cols = ['key_0', '1m^2 전용면적당 거래금액(만원)', '물가지수', 'GDP(십억원)', '기준금리(연%)']
seoul_merge2 = pd.DataFrame(seoul_merge, columns=cols)
seoul_merge2
# Out:
#       key_0  1m^2 전용면적당 거래금액(만원)     물가지수  GDP(십억원)  기준금리(연%)
# 0   2006/Q1                497.0   75.480  246614.4      4.00
# 1   2006/Q2                424.0   75.951  248152.7      4.25
# 2   2006/Q3                407.0   76.571  253912.6      4.50
# 3   2006/Q4                462.0   76.323  256921.7      4.50
# 4   2007/Q1                393.0   76.992  263441.3      4.50
# ..      ...                  ...      ...       ...       ...
# 63  2021/Q4               1443.0  103.750  530268.9      1.00
# 64  2022/Q1               1382.0  105.350  532765.7      1.25
# 65  2022/Q2               1452.0  107.540  540784.3      1.75
# 66  2022/Q3               1269.0  108.760  538803.8      2.50
# 67  2022/Q4               1249.0  109.200  539324.4      3.25
#
# [68 rows x 5 columns]

# %%
seoul_merge2

# %%
seoul_merge2.to_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\가격과 경제적요인 머지.csv", encoding="utf-8")

# %%
plt.xticks(rotation=90)
plt.plot(seoul_merge2['key_0'], seoul_merge2['1m^2 전용면적당 거래금액(만원)'], label="물가")

# %%
import plotly.graph_objs as go
import pandas as pd

# 데이터 프레임 df1이 이미 정의되어 있다고 가정합니다.

# 그래프에 사용할 x축을 설정합니다.
x_axis = seoul_merge2['key_0']

# 각 feature에 해당하는 y축 데이터를 설정합니다.
y1 = seoul_merge2['1m^2 전용면적당 거래금액(만원)']
y2 = seoul_merge2['물가지수']
y3 = seoul_merge2['GDP(십억원)']
y4 = seoul_merge2['기준금리(연%)']

# 그래프 객체를 생성합니다.
fig = go.Figure()

# trace를 추가합니다.
fig.add_trace(go.Scatter(x=x_axis, y=y1, name='1m^2 전용면적당 거래금액(만원)'))
fig.add_trace(go.Scatter(x=x_axis, y=y2, name='물가지수'))
fig.add_trace(go.Scatter(x=x_axis, y=y3, name='GDP(십억원)'))
fig.add_trace(go.Scatter(x=x_axis, y=y4, name='기준금리(연%)'))

# 그래프 레이아웃을 설정합니다.
fig.update_layout(title='시계열 그래프', xaxis_title='key_0', yaxis_title='값')

# 그래프를 출력합니다.
fig.show()
# Out:
# <div>                            <div id="e3e9e9c4-c2af-4358-bcf2-fa6f3bd8040b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e3e9e9c4-c2af-4358-bcf2-fa6f3bd8040b")) {                    Plotly.newPlot(                        "e3e9e9c4-c2af-4358-bcf2-fa6f3bd8040b",                        [{"name":"1m^2 \uc804\uc6a9\uba74\uc801\ub2f9 \uac70\ub798\uae08\uc561(\ub9cc\uc6d0)","x":["2006/Q1","2006/Q2","2006/Q3","2006/Q4","2007/Q1","2007/Q2","2007/Q3","2007/Q4","2008/Q1","2008/Q2","2008/Q3","2008/Q4","2009/Q1","2009/Q2","2009/Q3","2009/Q4","2010/Q1","2010/Q2","2010/Q3","2010/Q4","2011/Q1","2011/Q2","2011/Q3","2011/Q4","2012/Q1","2012/Q2","2012/Q3","2012/Q4","2013/Q1","2013/Q2","2013/Q3","2013/Q4","2014/Q1","2014/Q2","2014/Q3","2014/Q4","2015/Q1","2015/Q
# ...

# %%
plt.plot(seoul_merge2['물가지수'], seoul_merge2['1m^2 전용면적당 거래금액(만원)'], label="물가")

# %%
plt.scatter(seoul_merge2['기준금리(연%)'], seoul_merge2['1m^2 전용면적당 거래금액(만원)'], label="금리")

# %%
plt.scatter(seoul_merge2['GDP(십억원)'], seoul_merge2['1m^2 전용면적당 거래금액(만원)'], label="GDP")

# %%
seoul_pop_total.set_index("지역", inplace=True)

# %%
seoul_pop_total
# Out:
#           2006     2007     2008     2009     2010     2011     2012     2013  \
# 지역
# 서울특별시  3978938  4046086  4097562  4116660  4224181  4192752  4177970  4182351
#
#           2014     2015     2016     2017     2018     2019     2020     2021  \
# 지역
# 서울특별시  4194176  4189948  4189839  4220082  4263868  4327605  4417954  4426007
#
#           2022
# 지역
# 서울특별시  4446296

# %%
import sklearn
from sklearn import preprocessing

min_max_scale = sklearn.preprocessing.MinMaxScaler() #StandardScaler 표준화된 방식으로 수행

cols = ['1m^2 전용면적당 거래금액(만원)', '물가지수', 'GDP(십억원)', '기준금리(연%)']

X = seoul_merge2[cols].values
X

X_scaled = min_max_scale.fit_transform(X)
X_scaled #### 정규화 된 결과'

seoul_merge3 = pd.DataFrame(X_scaled, columns = cols, index = seoul_merge['key_0'])
seoul_merge3
# Out:
#          1m^2 전용면적당 거래금액(만원)      물가지수  GDP(십억원)  기준금리(연%)
# key_0
# 2006/Q1             0.098206  0.000000  0.000000  0.736842
# 2006/Q2             0.029273  0.013968  0.005229  0.789474
# 2006/Q3             0.013220  0.032355  0.024809  0.842105
# 2006/Q4             0.065156  0.025000  0.035039  0.842105
# 2007/Q1             0.000000  0.044840  0.057201  0.842105
# ...                      ...       ...       ...       ...
# 2021/Q4             0.991501  0.838375  0.964254  0.105263
# 2022/Q1             0.933900  0.885824  0.972742  0.157895
# 2022/Q2             1.000000  0.950771  1.000000  0.263158
# 2022/Q3             0.827195  0.986951  0.993267  0.421053
# 2022/Q4             0.808310  1.000000  0.995037  0.578947
#
# [68 rows x 4 columns]

# %%
seoul_merge4=seoul_merge3*100

# %%
seoul_merge4.to_csv("")

# %%
seoul_merge4.plot(kind="line")
# Out:
# <div>                            <div id="666f7ccb-5e34-478c-adb2-06e4b3d0df43" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("666f7ccb-5e34-478c-adb2-06e4b3d0df43")) {                    Plotly.newPlot(                        "666f7ccb-5e34-478c-adb2-06e4b3d0df43",                        [{"hovertemplate":"variable=1m^2 \uc804\uc6a9\uba74\uc801\ub2f9 \uac70\ub798\uae08\uc561(\ub9cc\uc6d0)<br>key_0=%{x}<br>value=%{y}<extra></extra>","legendgroup":"1m^2 \uc804\uc6a9\uba74\uc801\ub2f9 \uac70\ub798\uae08\uc561(\ub9cc\uc6d0)","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"1m^2 \uc804\uc6a9\uba74\uc801\ub2f9 \uac70\ub798\uae08\uc561(\ub9cc\uc6d0)","orientation":"v","showlegend":true,"x":["2006/Q1","2006/Q2"
# ...

# %%
seoul_merge4.to_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\정규화시킨 가격과 경제적 자료.csv", encoding="utf-8")
