# %% [markdown]
# ### 서울시 인구 이동

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mlp
import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname ="C:\\Windows\\Fonts\\malgun.ttf").get_name()
plt.rc('font',family=font_name)
mlp.rcParams['axes.unicode_minus']=False

# %%
seoul_pop = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\새 폴더\\시군구별_이동자수_20230410140037.csv", encoding='cp949')
seoul_pop
# Out:
#     행정구역(시군구)별     2017   2017.1   2017.2          2017.3             2017.4  \
# 0   행정구역(시군구)별  총전입 (명)  총전출 (명)  순이동 (명)  시도내이동-시군구내 (명)  시도내이동-시군구간 전입 (명)
# 1        서울특별시  1472937  1571423   -98486          454536             564271
# 2          종로구    28020    25814     2206            4512              14610
# 3           중구    20904    20574      330            3338              11189
# 4          용산구    35154    36622    -1468            7302              16054
# 5          성동구    50416    46031     4385           11151              25046
# 6          광진구    56010    56647     -637           16364              22011
# 7         동대문구    47899    52733    -4834           13489              18879
# 8          중랑구    56385    59947    -3562           22111              20569
# 9          성북구    61285    68221    -6936           20294              24663
# 10         강북구    42231    44809    -2578           14164              18237
# ...

# %%
for a in range(1, 9):
    seoul_pop.rename(columns={seoul_pop.columns[a] : '2017년'}, inplace=True)

for b in range(9, 17):
    seoul_pop.rename(columns={seoul_pop.columns[b] : '2018년'}, inplace=True)
for c in range(17, 25):
    seoul_pop.rename(columns={seoul_pop.columns[c] : '2019년'}, inplace=True)
for d in range(25, 33):
    seoul_pop.rename(columns={seoul_pop.columns[d] : '2020년'}, inplace=True)
for e in range(33, 41):
    seoul_pop.rename(columns={seoul_pop.columns[e] : '2021년'}, inplace=True)

for f in range(41, 49):
    seoul_pop.rename(columns={seoul_pop.columns[f] : '2022년'},inplace=True)

# %%
seoul_pop.rename(columns={"행정구역(시군구)별" : "연도"}, inplace=True)

# %%
seoul_pop
# Out:
#             연도    2017년    2017년    2017년           2017년              2017년  \
# 0   행정구역(시군구)별  총전입 (명)  총전출 (명)  순이동 (명)  시도내이동-시군구내 (명)  시도내이동-시군구간 전입 (명)
# 1        서울특별시  1472937  1571423   -98486          454536             564271
# 2          종로구    28020    25814     2206            4512              14610
# 3           중구    20904    20574      330            3338              11189
# 4          용산구    35154    36622    -1468            7302              16054
# 5          성동구    50416    46031     4385           11151              25046
# 6          광진구    56010    56647     -637           16364              22011
# 7         동대문구    47899    52733    -4834           13489              18879
# 8          중랑구    56385    59947    -3562           22111              20569
# 9          성북구    61285    68221    -6936           20294              24663
# 10         강북구    42231    44809    -2578           14164              18237
# ...

# %%
seoul_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 49 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연도      27 non-null     object
#  1   2017년   27 non-null     object
#  2   2017년   27 non-null     object
#  3   2017년   27 non-null     object
#  4   2017년   27 non-null     object
#  5   2017년   27 non-null     object
#  6   2017년   27 non-null     object
#  7   2017년   27 non-null     object
#  8   2017년   27 non-null     object
#  9   2018년   27 non-null     object
#  10  2018년   27 non-null     object
#  11  2018년   27 non-null     object
#  12  2018년   27 non-null     object
#  13  2018년   27 non-null     object
#  14  2018년   27 non-null     object
#  15  2018년   27 non-null     object
#  16  2018년   27 non-null     object
#  17  2019년   27 non-null     object
#  18  2019년   27 non-null     object
#  19  2019년   27 non-null     object
#  20  2019년   27 non-null     object
# ...

# %%
seoul_pop.to_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\새 폴더\\seoul_pop연도별.csv")

# %%
seoul_pop2 = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\새 폴더\\seoul_pop연도별.csv", header=[0,1], index_col=0)
seoul_pop2
# Out:
#            연도    2017년                                                    \
# 0  행정구역(시군구)별  총전입 (명)  총전출 (명) 순이동 (명) 시도내이동-시군구내 (명) 시도내이동-시군구간 전입 (명)
# 1       서울특별시  1472937  1571423  -98486         454536            564271
# 2         종로구    28020    25814    2206           4512             14610
# 3          중구    20904    20574     330           3338             11189
# 4         용산구    35154    36622   -1468           7302             16054
# 5         성동구    50416    46031    4385          11151             25046
# 6         광진구    56010    56647    -637          16364             22011
# 7        동대문구    47899    52733   -4834          13489             18879
# 8         중랑구    56385    59947   -3562          22111             20569
# 9         성북구    61285    68221   -6936          20294             24663
# 10        강북구    42231    44809   -2578          14164             18237
# 11        도봉구    40965    45260   -4295          13548             16966
# ...

# %%
seoul_pop2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 1 to 26
# Data columns (total 49 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   (연도, 행정구역(시군구)별)            26 non-null     object
#  1   (2017년, 총전입 (명))            26 non-null     int64
#  2   (2017년, 총전출 (명))            26 non-null     int64
#  3   (2017년, 순이동 (명))            26 non-null     int64
#  4   (2017년, 시도내이동-시군구내 (명))     26 non-null     int64
#  5   (2017년, 시도내이동-시군구간 전입 (명))  26 non-null     int64
#  6   (2017년, 시도내이동-시군구간 전출 (명))  26 non-null     int64
#  7   (2017년, 시도간전입 (명))          26 non-null     int64
#  8   (2017년, 시도간전출 (명))          26 non-null     int64
#  9   (2018년, 총전입 (명))            26 non-null     int64
#  10  (2018년, 총전출 (명))            26 non-null     int64
#  11  (2018년, 순이동 (명))            26 non-null     int64
#  12  (2018년, 시도내이동-시군구내 (명))     26 non-null     int64
# ...

# %% [markdown]
# ### 서울시 아파트 관심도

# %%
seoul_interest = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\부동산 관심도.csv", header=1)
seoul_interest
# Out:
#           월  서울시 아파트: (대한민국)
# 0   2017-01               57
# 1   2017-02               58
# 2   2017-03                0
# 3   2017-04               73
# 4   2017-05               75
# ..      ...              ...
# 71  2022-12               51
# 72  2023-01               33
# 73  2023-02               68
# 74  2023-03               54
# 75  2023-04               50
#
# [76 rows x 2 columns]

# %%
seoul_interest.rename(columns={'서울시 아파트: (대한민국)' : '서울시 아파트'}, inplace=True)

# %%
seoul_interest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   월        76 non-null     object
#  1   서울시 아파트  76 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.3+ KB

# %%
seoul_interest['서울시 아파트']=pd.to_numeric(seoul_interest['서울시 아파트'])

# %%
seoul_interest.to_csv("Data/data/부동산 파일/서울시 아파트 관심도.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_86668\1617753429.py in <module>
# ----> 1 seoul_interest.to_csv("Data/data/부동산 파일/서울시 아파트 관심도.csv")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3549         )
#    3550
# -> 3551         return DataFrameRenderer(formatter).to_csv(
#    3552             path_or_buf,
#    3553             line_terminator=line_terminator,
#
# ...

# %%
seoul_interest.plot(kind='line', x= '월', y = '서울시 아파트', title= '서울시 아파트의 관심도')
# Out:
# <AxesSubplot:title={'center':'서울시 아파트의 관심도'}, xlabel='월'>

# %%
seoul_apt_price = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\save_point3_apt_buysell_2018_data (2).csv", encoding='utf-8',index_col=0)
seoul_apt_price
# Out:
#           본번    부번  전용면적(㎡)      계약년월  거래금액(만원)  1m^2 전용면적당 거래금액(만원)    계약연도  \
# 자치구별
# 강남구    479.0   5.0     94.0  201805.0  153334.0               1702.0  2018.0
# 강동구    376.0   4.0     78.0  201805.0   64967.0                858.0  2018.0
# 강북구    768.0   8.0     78.0  201806.0   42267.0                563.0  2018.0
# 강서구    795.0   6.0     75.0  201805.0   53063.0                728.0  2018.0
# 관악구   1497.0  11.0     77.0  201805.0   47147.0                642.0  2018.0
# 광진구    519.0   5.0     87.0  201805.0   80294.0                943.0  2018.0
# 구로구    526.0  14.0     74.0  201806.0   43341.0                595.0  2018.0
# 금천구    874.0   4.0     76.0  201806.0   37864.0                516.0  2018.0
# 노원구    588.0   1.0     66.0  201806.0   38808.0                601.0  2018.0
# 도봉구    426.0   2.0     72.0  201806.0   35758.0                504.0  2018.0
# 동대문구   397.0   3.0     76.0  201805.0   50636.0                693.0  2018.0
# ...

# %%
seoul_apt_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   자치구별                 25 non-null     object
#  1   본번                   25 non-null     float64
#  2   부번                   25 non-null     float64
#  3   전용면적(㎡)              25 non-null     float64
#  4   계약년월                 25 non-null     float64
#  5   거래금액(만원)             25 non-null     float64
#  6   1m^2 전용면적당 거래금액(만원)  25 non-null     float64
#  7   계약연도                 25 non-null     float64
#  8   계약월                  25 non-null     float64
# dtypes: float64(8), object(1)
# memory usage: 1.9+ KB

# %%
seoul_pop3 =pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\seoul_pop연도별.csv", encoding='utf-8')
seoul_pop3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 28 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   연도          48 non-null     object
#  1   행정구역(시군구)별  48 non-null     object
#  2   서울특별시       48 non-null     int64
#  3   종로구         48 non-null     int64
#  4   중구          48 non-null     int64
#  5   용산구         48 non-null     int64
#  6   성동구         48 non-null     int64
#  7   광진구         48 non-null     int64
#  8   동대문구        48 non-null     int64
#  9   중랑구         48 non-null     int64
#  10  성북구         48 non-null     int64
#  11  강북구         48 non-null     int64
#  12  도봉구         48 non-null     int64
#  13  노원구         48 non-null     int64
#  14  은평구         48 non-null     int64
#  15  서대문구        48 non-null     int64
#  16  마포구         48 non-null     int64
#  17  양천구         48 non-null     int64
#  18  강서구         48 non-null     int64
# ...

# %%
seoul_pop3
# Out:
#        연도         행정구역(시군구)별    서울특별시    종로구     중구    용산구    성동구    광진구  \
# 0   2017년            총전입 (명)  1472937  28020  20904  35154  50416  56010
# 1   2017년            총전출 (명)  1571423  25814  20574  36622  46031  56647
# 2   2017년            순이동 (명)   -98486   2206    330  -1468   4385   -637
# 3   2017년     시도내이동-시군구내 (명)   454536   4512   3338   7302  11151  16364
# 4   2017년  시도내이동-시군구간 전입 (명)   564271  14610  11189  16054  25046  22011
# 5   2017년  시도내이동-시군구간 전출 (명)   564271  13178  11319  16866  20756  20936
# 6   2017년          시도간전입 (명)   454130   8898   6377  11798  14219  17635
# 7   2017년          시도간전출 (명)   552616   8124   5917  12454  14124  19347
# 8   2018년            총전입 (명)  1439707  23187  20771  37339  51358  55728
# 9   2018년            총전출 (명)  1549937  24798  20873  37801  49012  58774
# 10  2018년            순이동 (명)  -110230  -1611   -102   -462   2346  -3046
# 11  2018년     시도내이동-시군구내 (명)   430780   3807   3424   7853  12243  17036
# ...

# %%
seoul_pop.plot(kind="line")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_86668\4027659794.py in <module>
# ----> 1 seoul_pop.plot(kind="line")
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     325     def generate(self):
# ...

# %%
seoul_pop2.plot(kind="line")
# Out:
# <AxesSubplot:xlabel='연도'>

# %%
seoul_coffee = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\구별_월별_커피숍개수.csv",encoding='utf-8', index_col=0)
seoul_coffee
# Out:
#             구로구   서초구  영등포구  서대문구   강남구    중구  송파구  종로구  마포구  성북구  ...  은평구  \
# 2017-1-31   399   921   753   441  1586  1016  428  830  908  380  ...  347
# 2017-2-28   404   926   766   447  1586  1034  440  838  916  391  ...  352
# 2017-3-31   404   926   766   447  1586  1034  440  838  916  391  ...  352
# 2017-4-30   404   926   766   447  1586  1034  440  838  916  391  ...  352
# 2017-5-31   404   926   766   447  1586  1034  440  838  916  391  ...  352
# ...         ...   ...   ...   ...   ...   ...  ...  ...  ...  ...  ...  ...
# 2022-8-31   488  1012   899   496  1882  1166  792  873  930  559  ...  379
# 2022-9-30   488  1012   899   496  1882  1166  792  873  930  559  ...  379
# 2022-10-31  490  1014   903   513  1907  1168  788  877  921  559  ...  390
# 2022-11-30  491  1012   901   517  1892  1164  785  874  917  565  ...  385
# 2022-12-31  488  1012   899   496  1883  1166  792  873  930  559  ...  379
#
#              강서구  강동구  도봉구  금천구  양천구  관악구  노원구  광진구  성동구
# ...

# %%
seoul_coffee
# Out:
#       2017-1-31  2017-2-28  2017-3-31  2017-4-30  2017-5-31  2017-6-30  \
# 구로구         399        404        404        404        404        404
# 서초구         921        926        926        926        926        926
# 영등포구        753        766        766        766        766        766
# 서대문구        441        447        447        447        447        447
# 강남구        1586       1586       1586       1586       1586       1586
# 중구         1016       1034       1034       1034       1034       1034
# 송파구         428        440        440        440        440        440
# 종로구         830        838        838        838        838        838
# 마포구         908        916        916        916        916        916
# 성북구         380        391        391        391        391        391
# 동대문구        351        346        346        346        346        346
# 용산구         370        379        379        379        379        379
# ...

# %%
seoul_coffee=seoul_coffee.T
seoul_coffee
# Out:
#       2017-1-31  2017-2-28  2017-3-31  2017-4-30  2017-5-31  2017-6-30  \
# 구로구         399        404        404        404        404        404
# 서초구         921        926        926        926        926        926
# 영등포구        753        766        766        766        766        766
# 서대문구        441        447        447        447        447        447
# 강남구        1586       1586       1586       1586       1586       1586
# 중구         1016       1034       1034       1034       1034       1034
# 송파구         428        440        440        440        440        440
# 종로구         830        838        838        838        838        838
# 마포구         908        916        916        916        916        916
# 성북구         380        391        391        391        391        391
# 동대문구        351        346        346        346        346        346
# 용산구         370        379        379        379        379        379
# ...

# %%
seoul_merge = pd.merge(seoul_coffee, seoul_apt_price, left_on=seoul_coffee.index, right_on = seoul_apt_price.index)

# %%
seoul_merge
# Out:
#    key_0  2017-1-31  2017-2-28  2017-3-31  2017-4-30  2017-5-31  2017-6-30  \
# 0    구로구        399        404        404        404        404        404
# 1    서초구        921        926        926        926        926        926
# 2   영등포구        753        766        766        766        766        766
# 3   서대문구        441        447        447        447        447        447
# 4    강남구       1586       1586       1586       1586       1586       1586
# 5     중구       1016       1034       1034       1034       1034       1034
# 6    송파구        428        440        440        440        440        440
# 7    종로구        830        838        838        838        838        838
# 8    마포구        908        916        916        916        916        916
# 9    성북구        380        391        391        391        391        391
# 10  동대문구        351        346        346        346        346        346
# ...

# %%
sns.lmplot(x='2017-12-31', seoul_merge['1m^2 전용면적당 거래금액(만원)'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_86668\4093689706.py in <module>
# ----> 1 seoul_merge.scatterplot(seoul_merge['2017-12-31'], seoul_merge['1m^2 전용면적당 거래금액(만원)'])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'scatterplot'

# %%
seoul_merge=seoul_merge[['key_0', '2017-12-31', '2018-12-31', '2019-12-31', '2020-12-31', '2021-12-31', '2022-12-31', '1m^2 전용면적당 거래금액(만원)', '계약연도' ]]

# %%
seoul_merge
# Out:
#    key_0  2017-12-31  2018-12-31  2019-12-31  2020-12-31  2021-12-31  \
# 0    구로구         404         407         414         459         474
# 1    서초구         929         949         974        1005        1004
# 2   영등포구         766         799         844         864         916
# 3   서대문구         448         492         525         522         496
# 4    강남구        1589        1679        1794        1834        1873
# 5     중구        1034        1072        1135        1149        1148
# 6    송파구         440         445         476         585         692
# 7    종로구         838         877         896         862         850
# 8    마포구         916         943         851         755         906
# 9    성북구         391         433         455         492         524
# 10  동대문구         346         395         408         424         427
# 11   용산구         379         391         422         444         449
# 12   중랑구         234         247         296         329         367
# ...

# %%
seoul_merge.loc['평균']=(seoul_merge.sum(axis=0)/25)
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_86668\1878814322.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seoul_merge.loc['평균']=(seoul_merge.sum(axis=0)/25)

# %%
seoul_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, 구로구 to 평균
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   2018-12-31           26 non-null     float64
#  1   1m^2 전용면적당 거래금액(만원)  26 non-null     float64
# dtypes: float64(2)
# memory usage: 624.0+ bytes

# %%
seoul_merge
# Out:
#        2018-12-31  1m^2 전용면적당 거래금액(만원)
# key_0
# 구로구        407.00               595.00
# 서초구        949.00              1461.00
# 영등포구       799.00               845.00
# 서대문구       492.00               727.00
# 강남구       1679.00              1702.00
# 중구        1072.00               871.00
# 송파구        445.00              1201.00
# 종로구        877.00               764.00
# 마포구        943.00               989.00
# 성북구        433.00               629.00
# 동대문구       395.00               693.00
# 용산구        391.00              1200.00
# 중랑구        247.00               541.00
# 강북구        211.00               563.00
# 동작구        416.00               880.00
# 은평구        387.00               627.00
# 강서구        748.00               728.00
# 강동구        416.00               858.00
# 도봉구        229.00               504.00
# 금천구        324.00               516.00
# 양천구        357.00               811.00
# 관악구        479.00               642.00
# 노원구        433.00               601.00
# ...

# %%
seoul_merge.set_index('key_0', inplace=True)

# %%
seoul_merge.rename(columns={'key_0' : '구별'}, inplace=True)
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_86668\3637362194.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   seoul_merge.rename(columns={'key_0' : '구별'}, inplace=True)

# %%
seoul_merge.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='key_0'>

# %%
seoul_merge=seoul_merge[['2018-12-31', '1m^2 전용면적당 거래금액(만원)']]

# %%
seoul_merge.plot(kind="line")
# Out:
# <AxesSubplot:xlabel='key_0'>

# %%
plt.scatter(seoul_merge2['2018-12-31'], seoul_merge2['1m^2 전용면적당 거래금액(만원)'])

# %%
seoul_merge2 = pd.merge(seoul_merge, seoul_pop2, left_on=seoul_merge.index, right_on=seoul_pop2['연도', '행정구역(시군구)별'])
seoul_merge2
# Out:
# C:\Users\acorn\AppData\Local\Temp\ipykernel_86668\4124414762.py:1: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left, 2 on the right)
#   seoul_merge2 = pd.merge(seoul_merge, seoul_pop2, left_on=seoul_merge.index, right_on=seoul_pop2['연도', '행정구역(시군구)별'])
#    key_0  2018-12-31  1m^2 전용면적당 거래금액(만원) (연도, 행정구역(시군구)별)  (2017년, 총전입 (명))  \
# 0    구로구       407.0                595.0              구로구             50077
# 1    서초구       949.0               1461.0              서초구             68680
# 2   영등포구       799.0                845.0             영등포구             62622
# 3   서대문구       492.0                727.0             서대문구             48534
# 4    강남구      1679.0               1702.0              강남구             90474
# 5     중구      1072.0                871.0               중구             20904
# 6    송파구       445.0               1201.0              송파구            110872
# ...

# %%
plt.plot(seoul_pop2['행정구역(시군구)별'], seoul_pop2['2017년'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '행정구역(시군구)별'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
seoul_park = pd.read_csv("C:\\hojun13\\Pythonwork\\Analysis\\Data\\data\\부동산 파일\\프로젝트\\park_data.csv", encoding='utf-8')

# %%
seoul_park.set_index('자치구별', inplace=True)

# %%
seoul_merge2= pd.merge(seoul_merge, seoul_park, left_on=seoul_merge.index, right_on=seoul_park.index)

# %%
plt.scatter(seoul_merge2['공원수'], seoul_merge2['1m^2 전용면적당 거래금액(만원)'])
